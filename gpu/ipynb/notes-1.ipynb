# %%
import torch
import torch._numpy as tnp

# %%
a = torch.tensor([40.0, 80.0, 45.0])
print (a)
# Out:
# tensor([40., 80., 45.])

# %%
print(torch.softmax(a, dim=0))
# Out:
# tensor([4.2484e-18, 1.0000e+00, 6.3051e-16])

# %%
b = torch.tensor( [5.0, 10.0, 5.6])
print(torch.softmax(b, dim=0))
# Out:
# tensor([0.0066, 0.9813, 0.0120])
